# %%
import random
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Admission_Predict_Ver1.1.csv")

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
sof=[]
lor=[]
gpa=[]
y=[]
data = np.genfromtxt('https://raw.githubusercontent.com/nmit-406/image-processing-labs/master/forward-propa%2C10-22/Admission_Predict_Ver1.1.csv',delimiter=',')
for i in data:
    sof.append(i[4])
    lor.append(i[5])
    gpa.append(i[6])
    y.append(i[8])

# %%
def computeLoss(sof,lor,gpa,y):
    loss = 0
    n= len(sof)
    for j in range(n):
        ypre = (sof[j]*a+lor[j]*b+gpa[j]*c + d)*m + (sof[j]*e+lor[j]f + gpa[j]g + h)*k+l
        loss+=(ypre-y[j])**2
    return loss/n
# Out:
#   File "<ipython-input-28-202d3f4a0047>", line 5
#     ypre = (sof[j]*a+lor[j]*b+gpa[j]*c + d)*m + (sof[j]*e+lor[j]f + gpa[j]g + h)*k+l
#                                                                 ^
# SyntaxError: invalid syntax

# %%
def computeGrad(sof,lor,gpa,y,ki):
        n = len(sof)
        i=0
        for i in range(n):
            y1 = 2*((sof[i]*a+lor[i]*b+gpa[i]*c + d)*m + (sof[i]*e+lor[i]f + gpa[i]g + h)*k+l-y[i])
            grad=0
            if(ki=="a"):
                grad=y1*sof[i]*m
            if(ki=="b"):
                grad=y1*lor[i]*m
            if(ki=="c"):
                grad=y1*gpa[i]*m
            if(ki=="d"):
                grad=y1*m
            if(ki=="m"):
                grad=y1*(a*sof[i]+b*lor[i]+c*gpa[i]+d)
            if(ki=="e"):
                grad=y1*sof[i]*k
            if(ki=="f"):
                grad=y1*lor[i]*k
            if(ki=="g"):
                grad=y1*gpa[i]*k
            if(ki=="h"):
                grad=y1*k
            if(ki=="k"):
                grad=y1*(e*sof[i]+f*lor[i]+g*gpa[i]+h)
            if(doer=="l"):
                grad=y1
    return grad/n

# %%
a= np.random.random()
b= np.random.random()
c= np.random.random()
d= np.random.random()
e= np.random.random()
f= np.random.random()
g= np.random.random()
h= np.random.random()
k= np.random.random()
l= np.random.random()
m= np.random.random()
# arr= []
# arr.append(a)
# arr.append(b)
# arr.append(c)
# arr.append(d)
# arr.append(e)
# arr.append(f)
# arr.append(g)
# arr.append(h)
# arr.append(k)
# arr.append(l)
# arr.append(m)

# %%
epoch=1000
learning_rate=0.001
for i in range(0,epoch):
    print("appemt "+str(i)+": loss: "+str(computeLoss(sof,lor,gpa,y)))
    print("appemt "+str(i)+": a: "+str(a)
    print("appemt "+str(i)+": b: "+str(b)
    print("appemt "+str(i)+": c: "+str(c)
    print("appemt "+str(i)+": d: "+str(d)
    print("appemt "+str(i)+": e: "+str(e)
    print("appemt "+str(i)+": f: "+str(f)
    print("appemt "+str(i)+": g: "+str(g)
    print("appemt "+str(i)+": h: "+str(h)
    print("appemt "+str(i)+": k: "+str(k)
    print("appemt "+str(i)+": l: "+str(l)
    print("appemt "+str(i)+": m: "+str(m)
    a-=learning_rate*computeGrad(sof,lor,gpa,y,"a")
    b-=learning_rate*computeGrad(sof,lor,gpa,y,"b")
    c-=learning_rate*computeGrad(sof,lor,gpa,y,"c")
    d-=learning_rate*computeGrad(sof,lor,gpa,y,"d")
    e-=learning_rate*computeGrad(sof,lor,gpa,y,"e")
    f-=learning_rate*computeGrad(sof,lor,gpa,y,"f")
    g-=learning_rate*computeGrad(sof,lor,gpa,y,"g")
    h-=learning_rate*computeGrad(sof,lor,gpa,y,"h")
    k-=learning_rate*computeGrad(sof,lor,gpa,y,"k)
    l-=learning_rate*computeGrad(sof,lor,gpa,y,"l")
    m-=learning_rate*computeGrad(sof,lor,gpa,y,"m")
# Out:
#   File "<ipython-input-29-a9a3b21ae82a>", line 6
#     print("appemt "+str(i)+": b: "+str(b)
#         ^
# SyntaxError: invalid syntax

# %%
np.random.random()
# Out:
# 0.16109052052868522
